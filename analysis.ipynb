# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("data/attacks.csv",encoding = "ISO-8859-1")

# %% [markdown]
# # EXPLORING DATASET

# %%
df.shape #25.723 Lines and 24 columns
# Out:
# (25723, 24)

# %% [markdown]
# 25.723 lines and 24 columns

# %% [markdown]
# ### Brief look at our dataset

# %% [markdown]
# ![alt text](https://memegenerator.net/img/instances/40379228/let-me-take-a-look-at-this.jpg "Take a look")

# %%
df.sample(frac=0.1) #sample 10%  to take a first look into our data set
# Out:
#         Case Number                  Date    Year        Type    Country  \
# 16313           NaN                   NaN     NaN         NaN        NaN
# 16910           NaN                   NaN     NaN         NaN        NaN
# 11289           NaN                   NaN     NaN         NaN        NaN
# 22118           NaN                   NaN     NaN         NaN        NaN
# 5110   1928.03.28.R  Reported 28-Mar-1928  1928.0  Unprovoked  AUSTRALIA
# ...             ...                   ...     ...         ...        ...
# 19585           NaN                   NaN     NaN         NaN        NaN
# 4937     1934.08.05           05-Aug-1934  1934.0  Unprovoked        USA
# 20877           NaN                   NaN     NaN         NaN        NaN
# 3690     1964.03.05           05-Mar-1964  1964.0  Unprovoked        USA
# 8681              0                   NaN     NaN         NaN        NaN
#
#              Area                         Location      Activity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.describe().T #Year & original order are the only numeric values, although we already knew it lookin at df.info()
# Out:
#                  count         mean          std  min     25%     50%     75%  \
# Year            6300.0  1927.272381   281.116308  0.0  1942.0  1977.0  2005.0
# original order  6309.0  3155.999683  1821.396206  2.0  1579.0  3156.0  4733.0
#
#                    max
# Year            2018.0
# original order  6310.0

# %%
cleanest_columns = df.isnull().sum()
display(cleanest_columns.sort_values()) # The least Nan´s  in a column, the most valid data
# Out:
# Case Number               17021
# original order            19414
# Date                      19421
# Case Number.2             19421
# Case Number.1             19421
# href                      19421
# pdf                       19421
# href formula              19422
# Year                      19423
# Type                      19425
# Investigator or Source    19438
# Injury                    19449
# Country                   19471
# Name                      19631
# Area                      19876
# Fatal (Y/N)               19960
# Location                  19961
# Activity                  19965
# Sex                       19986
# Age                       22252
# Species                   22259
# Time                      22775
# Unnamed: 23               25721
# Unnamed: 22               25722
# dtype: int64

# %% [markdown]
# ### Exploring COLUMNS to see what´s inside

# %%
df.columns #Actual names of columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
display(df.Injury.unique())
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
display(df.Time.unique())
# Out:
# array(['18h00', '14h00  -15h00', '07h45', nan, 'Late afternoon', '17h00',
#        '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30', '10h40',
#        '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40', '08h00',
#        '17h35', '15h30', '07h30', '19h00, Dusk', 'Night', '16h00',
#        '15h01', '12h00', '13h45', '23h30', '09h00', '14h30', '18h30',
#        '12h30', '16h30', '18h45', '06h00', '10h00', '10h44', '13h19',
#        'Midday', '13h30', '10h45', '11h20', '11h45', '19h30', '08h30',
#        '15h45', 'Shortly before 12h00', '17h34', '17h10', '11h15',
#        '08h50', '17h45', '13h00', '10h20', '13h20', '02h00', '09h50',
#        '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15', '15h40',
#        '19h05', '1300', '14h30 / 15h30', '22h00', '16h20', '14h34',
#        '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
# ...

# %%
display(df..unique())

# %%
display(df["Unnamed: 22"].unique())
# Out:
# array([nan, 'stopped here'], dtype=object)

# %%
display(df["Unnamed: 23"].unique())
# Out:
# array([nan, 'Teramo', 'change filename'], dtype=object)

# %%
display(df['Case Number.1'].unique())
# Out:
# array(['2018.06.25', '2018.06.18', '2018.06.09', ..., 'ND.0002',
#        'ND.0001', nan], dtype=object)

# %%
display(df['Case Number.2'].unique())
# Out:
# array(['2018.06.25', '2018.06.18', '2018.06.09', ..., 'ND.0002',
#        'ND.0001', nan], dtype=object)

# %%
display(df['href formula'].unique())
# Out:
# array(['http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf',
#        ...,
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0003-Ocracoke_1900-1905.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0002-JulesPatterson.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directoryND-0001-Ceylon.pdf'],
#       dtype=object)

# %%
display(df['Type'].unique())
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
display(df['Case Number'].unique())
# Out:
# array(['2018.06.25', '2018.06.18', '2018.06.09', ..., 'ND.0001', '0',
#        'xx'], dtype=object)

# %%
display(df['Injury'].unique())
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
display(df['Fatal (Y/N)'].unique()) # Needs cleaning
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
display(df['Investigator or Source'].unique())
# Out:
# array(['R. Collier, GSAF', 'K.McMurray, TrackingSharks.com',
#        'B. Myatt, GSAF', ..., 'F. Schwartz, p.23; C. Creswell, GSAF',
#        'The Sun, 10/20/1938', 'S.W. Baker'], dtype=object)

# %%
display(df['Fatal (Y/N)'].unique())
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %% [markdown]
# ### With this first look at shark´s data set:
# * Depending on the column working, we´ll have betweem 8 and 6 thousand valid lines from our original **25.723** rows
# * I can drop several columns with unnecessary like: 'Case Number','Investigator or Source', 'pdf', 'href formula', 'href',  'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22','Unnamed: 23'

# %% [markdown]
# # HYPOTHESIS

# %% [markdown]
# ### 1 - Swimming is not the most dangerous activity
# ### 2 - The deadliest ones are white sharks.

# %% [markdown]
# Cleaning of dataset work continues in `clean.ipynb` [HERE](clean.ipynb) #Meter emoji archivo, por que no lo pilla?

# %%
df.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
list(df["Species "].unique())
# Out:
# ['White shark',
#  nan,
#  '2 m shark',
#  'Tiger shark, 3m',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'Shark involvement not confirmed',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'Bull shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'White shark, 4.5 m',
# ...
